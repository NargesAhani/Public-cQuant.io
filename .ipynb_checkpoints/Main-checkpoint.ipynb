# %%
import pandas as pd
import numpy as np

import os

# %% [markdown]
# # Task 1

# %%
Project_path = os.getcwd()
print (Project_path)
# Out:
# C:\Users\nahani\Dropbox\Public-cQuant.io

# %%
Data_folder = Project_path+'\\Data'
Output_folder = Project_path+'\\Output'

# %%
contracts =  pd.read_csv(os.path.join(Data_folder+'\\contracts', 'Contracts.csv'))

fuelPrices_GDA_TETSTX = pd.read_csv(os.path.join(Data_folder+'\\fuelPrices', 'GDA_TETSTX.csv'))
fuelPrices_Henry_Hub = pd.read_csv(os.path.join(Data_folder+'\\fuelPrices', 'Henry Hub.csv'))

plantParameters = pd.read_csv(os.path.join(Data_folder+'\\plantParameters', 'Plant_Parameters.csv'))

powerPrices_2016 = pd.read_csv(os.path.join(Data_folder+'\\powerPrices', 'ERCOT_DA_Prices_2016.csv'))
powerPrices_2017 = pd.read_csv(os.path.join(Data_folder+'\\powerPrices', 'ERCOT_DA_Prices_2017.csv'))
powerPrices_2018 = pd.read_csv(os.path.join(Data_folder+'\\powerPrices', 'ERCOT_DA_Prices_2018.csv'))
powerPrices_2019 = pd.read_csv(os.path.join(Data_folder+'\\powerPrices', 'ERCOT_DA_Prices_2019.csv'))

# %%
fuelPrices = pd.concat([fuelPrices_GDA_TETSTX , fuelPrices_Henry_Hub])

# %%
powerPrices = pd.concat([powerPrices_2016, powerPrices_2017, powerPrices_2018, powerPrices_2019])

# %% [markdown]
# # Task 2

# %%
powerPrices['Y-M'] = pd.to_datetime(powerPrices['Date']).dt.strftime('%m/%Y')

# %%
grouped = powerPrices.groupby(['SettlementPoint','Y-M']).agg({'Price': ['mean', 'min', 'max', 'std']})

# %%
grouped
# Out:
#                              Price
#                               mean   min      max        std
# SettlementPoint Y-M
# HB_BUSAVG       01/2016  19.209301  5.12    54.69   5.485210
#                 01/2017  23.252782  1.94    96.28   7.471613
#                 01/2018  37.869677  5.83  1660.04  87.563613
#                 01/2019  24.592567  5.72    75.28   8.130355
#                 02/2016  15.288247  1.79    50.98   5.777172
# ...                            ...   ...      ...        ...
# LZ_WEST         11/2019  49.340847  3.60   286.91  31.876126
#                 12/2016  25.165820  0.37   139.73  11.654195
#                 12/2017  21.872258 -1.49    64.70   7.489398
#                 12/2018  34.980847  3.05   131.59  15.254886
#                 12/2019  39.502594  7.32   195.71  27.975862
#
# [681 rows x 4 columns]

# %% [markdown]
# # Task 3

# %% [markdown]
# I'll get back to it

# %% [markdown]
# # Task 4

# %%
grouped.columns.to_list()
# grouped_df = pd.DataFrame(grouped, columns=[''])
# Out:
# [('Price', 'mean'), ('Price', 'min'), ('Price', 'max'), ('Price', 'std')]

# %%
grouped.columns = ['Mean', 'Min', 'Max', 'SD']

# %%
grouped.reset_index(inplace=True)

# %%
grouped['Year'] = grouped['Y-M'].apply(lambda x: x.split('/')[1])
grouped['Month'] = grouped['Y-M'].apply(lambda x: x.split('/')[0])

# %%
grouped.drop(['Y-M'],  axis=1, inplace=True)

# %%
grouped.to_csv(os.path.join(Output_folder, 'MonthlyPowerPriceStatistics.csv'))

# %% [markdown]
# # Task 5

# %%
contracts
# Out:
#   ContractName         DealType   StartDate     EndDate  Volume Granularity  \
# 0           S1             Swap  2017-01-01  2017-03-31   20000       Daily
# 1           S2             Swap  2017-01-01  2018-12-31    1000      Hourly
# 2           O1  European option  2017-06-01  2017-07-15   10000       Daily
# 3           O2  European option  2018-10-01  2019-09-30    1000      Hourly
#
#    StrikePrice  Premium   PriceName
# 0          3.0      NaN   Henry Hub
# 1         21.0      NaN    HB_NORTH
# 2          2.9      0.1  GDA_TETSTX
# 3         31.5      3.0  HB_HOUSTON

# %%
contracts_hourly = contracts[contracts['Granularity'] == 'Hourly']
contracts_daily = contracts[contracts['Granularity'] == 'Daily']

# %%
contracts_daily
# Out:
#   ContractName         DealType   StartDate     EndDate  Volume Granularity  \
# 0           S1             Swap  2017-01-01  2017-03-31   20000       Daily
# 2           O1  European option  2017-06-01  2017-07-15   10000       Daily
#
#    StrikePrice  Premium   PriceName
# 0          3.0      NaN   Henry Hub
# 2          2.9      0.1  GDA_TETSTX

# %%
contracts_hourly
# Out:
#   ContractName         DealType   StartDate     EndDate  Volume Granularity  \
# 1           S2             Swap  2017-01-01  2018-12-31    1000      Hourly
# 3           O2  European option  2018-10-01  2019-09-30    1000      Hourly
#
#    StrikePrice  Premium   PriceName
# 1         21.0      NaN    HB_NORTH
# 3         31.5      3.0  HB_HOUSTON

# %%
contracts_daily['Date'] = [pd.date_range(s, e, freq='d') for s, e in
              zip(pd.to_datetime(contracts_daily['StartDate']),
                  pd.to_datetime(contracts_daily['EndDate']))]

contracts_daily = contracts_daily.explode('Date').drop(['StartDate', 'EndDate'], axis=1)
# Out:
# <ipython-input-80-99b764c7e2ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contracts_daily['Date'] = [pd.date_range(s, e, freq='d') for s, e in

# %%
contracts_daily
# Out:
#    ContractName         DealType  Volume Granularity  StrikePrice  Premium  \
# 0            S1             Swap   20000       Daily          3.0      NaN
# 0            S1             Swap   20000       Daily          3.0      NaN
# 0            S1             Swap   20000       Daily          3.0      NaN
# 0            S1             Swap   20000       Daily          3.0      NaN
# 0            S1             Swap   20000       Daily          3.0      NaN
# ..          ...              ...     ...         ...          ...      ...
# 2            O1  European option   10000       Daily          2.9      0.1
# 2            O1  European option   10000       Daily          2.9      0.1
# 2            O1  European option   10000       Daily          2.9      0.1
# 2            O1  European option   10000       Daily          2.9      0.1
# 2            O1  European option   10000       Daily          2.9      0.1
#
#      PriceName       Date
# 0    Henry Hub 2017-01-01
# 0    Henry Hub 2017-01-02
# 0    Henry Hub 2017-01-03
# 0    Henry Hub 2017-01-04
# 0    Henry Hub 2017-01-05
# ..         ...        ...
# 2   GDA_TETSTX 2017-07-11
# 2   GDA_TETSTX 2017-07-12
# 2   GDA_TETSTX 2017-07-13
# 2   GDA_TETSTX 2017-07-14
# 2   GDA_TETSTX 2017-07-15
#
# [135 rows x 8 columns]

# %%
contracts_hourly['Date'] = [pd.date_range(s, e, freq='1H') for s, e in
              zip(pd.to_datetime(contracts_hourly['StartDate']),
                  pd.to_datetime(contracts_hourly['EndDate']))]

contracts_hourly = contracts_hourly.explode('Date').drop(['StartDate', 'EndDate'], axis=1)
# Out:
# <ipython-input-82-f953e24bd43c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contracts_hourly['Date'] = [pd.date_range(s, e, freq='1H') for s, e in

# %%
contracts_hourly
# Out:
#    ContractName         DealType  Volume Granularity  StrikePrice  Premium  \
# 1            S2             Swap    1000      Hourly         21.0      NaN
# 1            S2             Swap    1000      Hourly         21.0      NaN
# 1            S2             Swap    1000      Hourly         21.0      NaN
# 1            S2             Swap    1000      Hourly         21.0      NaN
# 1            S2             Swap    1000      Hourly         21.0      NaN
# ..          ...              ...     ...         ...          ...      ...
# 3            O2  European option    1000      Hourly         31.5      3.0
# 3            O2  European option    1000      Hourly         31.5      3.0
# 3            O2  European option    1000      Hourly         31.5      3.0
# 3            O2  European option    1000      Hourly         31.5      3.0
# 3            O2  European option    1000      Hourly         31.5      3.0
#
#      PriceName                Date
# 1     HB_NORTH 2017-01-01 00:00:00
# 1     HB_NORTH 2017-01-01 01:00:00
# 1     HB_NORTH 2017-01-01 02:00:00
# 1     HB_NORTH 2017-01-01 03:00:00
# 1     HB_NORTH 2017-01-01 04:00:00
# ..         ...                 ...
# 3   HB_HOUSTON 2019-09-29 20:00:00
# 3   HB_HOUSTON 2019-09-29 21:00:00
# 3   HB_HOUSTON 2019-09-29 22:00:00
# 3   HB_HOUSTON 2019-09-29 23:00:00
# 3   HB_HOUSTON 2019-09-30 00:00:00
#
# [26234 rows x 8 columns]

# %% [markdown]
# # Task 6

# %%
#fuel prices for daily contracts
contracts_daily['Date'] = pd.to_datetime(contracts_daily['Date'])
fuelPrices['Date'] = pd.to_datetime(fuelPrices['Date'])

contracts_daily_fuelPrices = pd.merge(contracts_daily, fuelPrices,  
                                      how='left', 
                                      left_on=['PriceName','Date'], 
                                      right_on = ['Variable','Date'])

# %%
contracts_daily_fuelPrices
# Out:
#     ContractName         DealType  Volume Granularity  StrikePrice  Premium  \
# 0             S1             Swap   20000       Daily          3.0      NaN
# 1             S1             Swap   20000       Daily          3.0      NaN
# 2             S1             Swap   20000       Daily          3.0      NaN
# 3             S1             Swap   20000       Daily          3.0      NaN
# 4             S1             Swap   20000       Daily          3.0      NaN
# ..           ...              ...     ...         ...          ...      ...
# 130           O1  European option   10000       Daily          2.9      0.1
# 131           O1  European option   10000       Daily          2.9      0.1
# 132           O1  European option   10000       Daily          2.9      0.1
# 133           O1  European option   10000       Daily          2.9      0.1
# 134           O1  European option   10000       Daily          2.9      0.1
#
#       PriceName       Date    Variable  Price
# 0     Henry Hub 2017-01-01   Henry Hub  3.650
# 1     Henry Hub 2017-01-02   Henry Hub  3.650
# 2     Henry Hub 2017-01-03   Henry Hub  3.650
# 3     Henry Hub 2017-01-04   Henry Hub  3.390
# 4     Henry Hub 2017-01-05   Henry Hub  3.370
# ..          ...        ...         ...    ...
# 130  GDA_TETSTX 2017-07-11  GDA_TETSTX  2.910
# 131  GDA_TETSTX 2017-07-12  GDA_TETSTX  2.910
# 132  GDA_TETSTX 2017-07-13  GDA_TETSTX  2.915
# 133  GDA_TETSTX 2017-07-14  GDA_TETSTX  2.865
# 134  GDA_TETSTX 2017-07-15  GDA_TETSTX  2.935
#
# [135 rows x 10 columns]

# %%
# power prices for hourly contracts

contracts_hourly['Date'] = pd.to_datetime(contracts_hourly['Date'])
powerPrices['Date'] = pd.to_datetime(powerPrices['Date'])

contracts_hourly_powerPrices = pd.merge(contracts_hourly, powerPrices,  
                                      how='left', 
                                      left_on=['PriceName','Date'], 
                                      right_on = ['SettlementPoint','Date'])

# %%
contracts_hourly_powerPrices
# Out:
#       ContractName         DealType  Volume Granularity  StrikePrice  Premium  \
# 0               S2             Swap    1000      Hourly         21.0      NaN
# 1               S2             Swap    1000      Hourly         21.0      NaN
# 2               S2             Swap    1000      Hourly         21.0      NaN
# 3               S2             Swap    1000      Hourly         21.0      NaN
# 4               S2             Swap    1000      Hourly         21.0      NaN
# ...            ...              ...     ...         ...          ...      ...
# 26229           O2  European option    1000      Hourly         31.5      3.0
# 26230           O2  European option    1000      Hourly         31.5      3.0
# 26231           O2  European option    1000      Hourly         31.5      3.0
# 26232           O2  European option    1000      Hourly         31.5      3.0
# 26233           O2  European option    1000      Hourly         31.5      3.0
#
#         PriceName                Date SettlementPoint  Price      Y-M
# 0        HB_NORTH 2017-01-01 00:00:00        HB_NORTH  23.23  01/2017
# 1        HB_NORTH 2017-01-01 01:00:00        HB_NORTH  21.82  01/2017
# 2        HB_NORTH 2017-01-01 02:00:00        HB_NORTH  20.16  01/2017
# 3        HB_NORTH 2017-01-01 03:00:00        HB_NORTH  20.00  01/2017
# 4        HB_NORTH 2017-01-01 04:00:00        HB_NORTH  20.24  01/2017
# ...           ...                 ...             ...    ...      ...
# 26229  HB_HOUSTON 2019-09-29 20:00:00      HB_HOUSTON  23.71  09/2019
# 26230  HB_HOUSTON 2019-09-29 21:00:00      HB_HOUSTON  20.95  09/2019
# 26231  HB_HOUSTON 2019-09-29 22:00:00      HB_HOUSTON  18.56  09/2019
# 26232  HB_HOUSTON 2019-09-29 23:00:00      HB_HOUSTON  17.89  09/2019
# 26233  HB_HOUSTON 2019-09-30 00:00:00      HB_HOUSTON  16.48  09/2019
#
# [26234 rows x 11 columns]

# %% [markdown]
# # Task 7

# %%
contracts_hourly_powerPrices.fillna(0)
# Out:
#       ContractName         DealType  Volume Granularity  StrikePrice  Premium  \
# 0               S2             Swap    1000      Hourly         21.0      0.0
# 1               S2             Swap    1000      Hourly         21.0      0.0
# 2               S2             Swap    1000      Hourly         21.0      0.0
# 3               S2             Swap    1000      Hourly         21.0      0.0
# 4               S2             Swap    1000      Hourly         21.0      0.0
# ...            ...              ...     ...         ...          ...      ...
# 26229           O2  European option    1000      Hourly         31.5      3.0
# 26230           O2  European option    1000      Hourly         31.5      3.0
# 26231           O2  European option    1000      Hourly         31.5      3.0
# 26232           O2  European option    1000      Hourly         31.5      3.0
# 26233           O2  European option    1000      Hourly         31.5      3.0
#
#         PriceName                Date SettlementPoint  Price      Y-M
# 0        HB_NORTH 2017-01-01 00:00:00        HB_NORTH  23.23  01/2017
# 1        HB_NORTH 2017-01-01 01:00:00        HB_NORTH  21.82  01/2017
# 2        HB_NORTH 2017-01-01 02:00:00        HB_NORTH  20.16  01/2017
# 3        HB_NORTH 2017-01-01 03:00:00        HB_NORTH  20.00  01/2017
# 4        HB_NORTH 2017-01-01 04:00:00        HB_NORTH  20.24  01/2017
# ...           ...                 ...             ...    ...      ...
# 26229  HB_HOUSTON 2019-09-29 20:00:00      HB_HOUSTON  23.71  09/2019
# 26230  HB_HOUSTON 2019-09-29 21:00:00      HB_HOUSTON  20.95  09/2019
# 26231  HB_HOUSTON 2019-09-29 22:00:00      HB_HOUSTON  18.56  09/2019
# 26232  HB_HOUSTON 2019-09-29 23:00:00      HB_HOUSTON  17.89  09/2019
# 26233  HB_HOUSTON 2019-09-30 00:00:00      HB_HOUSTON  16.48  09/2019
#
# [26234 rows x 11 columns]

# %%
contracts_daily_fuelPrices.fillna(0)
# Out:
#     ContractName         DealType  Volume Granularity  StrikePrice  Premium  \
# 0             S1             Swap   20000       Daily          3.0      0.0
# 1             S1             Swap   20000       Daily          3.0      0.0
# 2             S1             Swap   20000       Daily          3.0      0.0
# 3             S1             Swap   20000       Daily          3.0      0.0
# 4             S1             Swap   20000       Daily          3.0      0.0
# ..           ...              ...     ...         ...          ...      ...
# 130           O1  European option   10000       Daily          2.9      0.1
# 131           O1  European option   10000       Daily          2.9      0.1
# 132           O1  European option   10000       Daily          2.9      0.1
# 133           O1  European option   10000       Daily          2.9      0.1
# 134           O1  European option   10000       Daily          2.9      0.1
#
#       PriceName       Date    Variable  Price
# 0     Henry Hub 2017-01-01   Henry Hub  3.650
# 1     Henry Hub 2017-01-02   Henry Hub  3.650
# 2     Henry Hub 2017-01-03   Henry Hub  3.650
# 3     Henry Hub 2017-01-04   Henry Hub  3.390
# 4     Henry Hub 2017-01-05   Henry Hub  3.370
# ..          ...        ...         ...    ...
# 130  GDA_TETSTX 2017-07-11  GDA_TETSTX  2.910
# 131  GDA_TETSTX 2017-07-12  GDA_TETSTX  2.910
# 132  GDA_TETSTX 2017-07-13  GDA_TETSTX  2.915
# 133  GDA_TETSTX 2017-07-14  GDA_TETSTX  2.865
# 134  GDA_TETSTX 2017-07-15  GDA_TETSTX  2.935
#
# [135 rows x 10 columns]

# %%
contracts_daily_fuelPrices['max_price_strike'] = np.where(contracts_daily_fuelPrices['Price']-contracts_daily_fuelPrices['StrikePrice']>0,
                                                         contracts_daily_fuelPrices['Price']-contracts_daily_fuelPrices['StrikePrice'],
                                                         0)

# %%
# • Swaps: (AssetPrice – StrikePrice) x Volume
# • Options: [MAX(AssetPrice – StrikePrice, 0) - Premium] x Volume
contracts_daily_fuelPrices['payoffs'] = np.where(
 contracts_daily_fuelPrices['DealType'] == 'Swap',
 (contracts_daily_fuelPrices['Price']-contracts_daily_fuelPrices['StrikePrice'])*contracts_daily_fuelPrices['Volume'],
 (contracts_daily_fuelPrices['max_price_strike']-contracts_daily_fuelPrices['Premium'])*contracts_daily_fuelPrices['Volume']
)

# %%
contracts_daily_fuelPrices
# Out:
#     ContractName         DealType  Volume Granularity  StrikePrice  Premium  \
# 0             S1             Swap   20000       Daily          3.0      NaN
# 1             S1             Swap   20000       Daily          3.0      NaN
# 2             S1             Swap   20000       Daily          3.0      NaN
# 3             S1             Swap   20000       Daily          3.0      NaN
# 4             S1             Swap   20000       Daily          3.0      NaN
# ..           ...              ...     ...         ...          ...      ...
# 130           O1  European option   10000       Daily          2.9      0.1
# 131           O1  European option   10000       Daily          2.9      0.1
# 132           O1  European option   10000       Daily          2.9      0.1
# 133           O1  European option   10000       Daily          2.9      0.1
# 134           O1  European option   10000       Daily          2.9      0.1
#
#       PriceName       Date    Variable  Price  payoffs  max_price_strike
# 0     Henry Hub 2017-01-01   Henry Hub  3.650  13000.0             0.650
# 1     Henry Hub 2017-01-02   Henry Hub  3.650  13000.0             0.650
# 2     Henry Hub 2017-01-03   Henry Hub  3.650  13000.0             0.650
# 3     Henry Hub 2017-01-04   Henry Hub  3.390   7800.0             0.390
# 4     Henry Hub 2017-01-05   Henry Hub  3.370   7400.0             0.370
# ..          ...        ...         ...    ...      ...               ...
# 130  GDA_TETSTX 2017-07-11  GDA_TETSTX  2.910   -900.0             0.010
# 131  GDA_TETSTX 2017-07-12  GDA_TETSTX  2.910   -900.0             0.010
# 132  GDA_TETSTX 2017-07-13  GDA_TETSTX  2.915   -850.0             0.015
# 133  GDA_TETSTX 2017-07-14  GDA_TETSTX  2.865  -1000.0             0.000
# 134  GDA_TETSTX 2017-07-15  GDA_TETSTX  2.935   -650.0             0.035
#
# [135 rows x 12 columns]

# %%
contracts_hourly_powerPrices['max_price_strike'] = np.where(contracts_hourly_powerPrices['Price']-contracts_hourly_powerPrices['StrikePrice']>0,
         contracts_hourly_powerPrices['Price']-contracts_hourly_powerPrices['StrikePrice'],
                                                         0)

# %%
contracts_hourly_powerPrices['payoffs'] = np.where(
 contracts_hourly_powerPrices['DealType'] == 'Swap',
 (contracts_hourly_powerPrices['Price']-contracts_hourly_powerPrices['StrikePrice'])*contracts_hourly_powerPrices['Volume'],
 (contracts_hourly_powerPrices['max_price_strike']-contracts_hourly_powerPrices['Premium'])*contracts_hourly_powerPrices['Volume']
)

# %%
contracts_hourly_powerPrices
# Out:
#       ContractName         DealType  Volume Granularity  StrikePrice  Premium  \
# 0               S2             Swap    1000      Hourly         21.0      NaN
# 1               S2             Swap    1000      Hourly         21.0      NaN
# 2               S2             Swap    1000      Hourly         21.0      NaN
# 3               S2             Swap    1000      Hourly         21.0      NaN
# 4               S2             Swap    1000      Hourly         21.0      NaN
# ...            ...              ...     ...         ...          ...      ...
# 26229           O2  European option    1000      Hourly         31.5      3.0
# 26230           O2  European option    1000      Hourly         31.5      3.0
# 26231           O2  European option    1000      Hourly         31.5      3.0
# 26232           O2  European option    1000      Hourly         31.5      3.0
# 26233           O2  European option    1000      Hourly         31.5      3.0
#
#         PriceName                Date SettlementPoint  Price      Y-M  \
# 0        HB_NORTH 2017-01-01 00:00:00        HB_NORTH  23.23  01/2017
# 1        HB_NORTH 2017-01-01 01:00:00        HB_NORTH  21.82  01/2017
# 2        HB_NORTH 2017-01-01 02:00:00        HB_NORTH  20.16  01/2017
# 3        HB_NORTH 2017-01-01 03:00:00        HB_NORTH  20.00  01/2017
# 4        HB_NORTH 2017-01-01 04:00:00        HB_NORTH  20.24  01/2017
# ...           ...                 ...             ...    ...      ...
# 26229  HB_HOUSTON 2019-09-29 20:00:00      HB_HOUSTON  23.71  09/2019
# 26230  HB_HOUSTON 2019-09-29 21:00:00      HB_HOUSTON  20.95  09/2019
# 26231  HB_HOUSTON 2019-09-29 22:00:00      HB_HOUSTON  18.56  09/2019
# 26232  HB_HOUSTON 2019-09-29 23:00:00      HB_HOUSTON  17.89  09/2019
# 26233  HB_HOUSTON 2019-09-30 00:00:00      HB_HOUSTON  16.48  09/2019
#
#        max_price_strike  payoffs
# 0                  2.23   2230.0
# 1                  0.82    820.0
# 2                  0.00   -840.0
# 3                  0.00  -1000.0
# 4                  0.00   -760.0
# ...                 ...      ...
# 26229              0.00  -3000.0
# 26230              0.00  -3000.0
# 26231              0.00  -3000.0
# 26232              0.00  -3000.0
# 26233              0.00  -3000.0
#
# [26234 rows x 13 columns]

# %% [markdown]
# # Task 8

# %%
contracts_daily_fuelPrices ['Y-M'] = pd.to_datetime(contracts_daily_fuelPrices['Date']).dt.strftime('%m/%Y')

# %%
contracts_daily_fuelPrices
# Out:
#     ContractName         DealType  Volume Granularity  StrikePrice  Premium  \
# 0             S1             Swap   20000       Daily          3.0      NaN
# 1             S1             Swap   20000       Daily          3.0      NaN
# 2             S1             Swap   20000       Daily          3.0      NaN
# 3             S1             Swap   20000       Daily          3.0      NaN
# 4             S1             Swap   20000       Daily          3.0      NaN
# ..           ...              ...     ...         ...          ...      ...
# 130           O1  European option   10000       Daily          2.9      0.1
# 131           O1  European option   10000       Daily          2.9      0.1
# 132           O1  European option   10000       Daily          2.9      0.1
# 133           O1  European option   10000       Daily          2.9      0.1
# 134           O1  European option   10000       Daily          2.9      0.1
#
#       PriceName       Date    Variable  Price  payoffs  max_price_strike  \
# 0     Henry Hub 2017-01-01   Henry Hub  3.650  13000.0             0.650
# 1     Henry Hub 2017-01-02   Henry Hub  3.650  13000.0             0.650
# 2     Henry Hub 2017-01-03   Henry Hub  3.650  13000.0             0.650
# 3     Henry Hub 2017-01-04   Henry Hub  3.390   7800.0             0.390
# 4     Henry Hub 2017-01-05   Henry Hub  3.370   7400.0             0.370
# ..          ...        ...         ...    ...      ...               ...
# 130  GDA_TETSTX 2017-07-11  GDA_TETSTX  2.910   -900.0             0.010
# 131  GDA_TETSTX 2017-07-12  GDA_TETSTX  2.910   -900.0             0.010
# 132  GDA_TETSTX 2017-07-13  GDA_TETSTX  2.915   -850.0             0.015
# 133  GDA_TETSTX 2017-07-14  GDA_TETSTX  2.865  -1000.0             0.000
# 134  GDA_TETSTX 2017-07-15  GDA_TETSTX  2.935   -650.0             0.035
#
#          Y-M
# 0    01/2017
# 1    01/2017
# 2    01/2017
# 3    01/2017
# 4    01/2017
# ..       ...
# 130  07/2017
# 131  07/2017
# 132  07/2017
# 133  07/2017
# 134  07/2017
#
# [135 rows x 13 columns]

# %%
grouped_1 = contracts_daily_fuelPrices.groupby(['ContractName','Y-M']).agg({'payoffs': ['sum']})

# %%
grouped_1
# Out:
#                        payoffs
#                            sum
# ContractName Y-M
# O1           06/2017  -20100.0
#              07/2017  -14300.0
# S1           01/2017  198300.0
#              02/2017  -97700.0
#              03/2017  -97700.0

# %%
grouped_2 = contracts_hourly_powerPrices.groupby(['ContractName','Y-M']).agg({'payoffs': ['sum']})

# %%
grouped_2
# Out:
#                          payoffs
#                              sum
# ContractName Y-M
# O2           01/2019  -1320540.0
#              02/2019  -1680820.0
#              03/2019    678800.0
#              04/2019   -730570.0
#              05/2019  -1097720.0
#              06/2019    773630.0
#              07/2019   3355940.0
#              08/2019  75340320.0
#              09/2019  39174380.0
#              10/2018    507430.0
#              11/2018    598010.0
#              12/2018     43140.0
# S2           01/2017   1481940.0
#              01/2018  12339910.0
#              02/2017  -1042810.0
#              02/2018    515440.0
#              03/2017    169240.0
#              03/2018   1194750.0
#              04/2017    295600.0
#              04/2018   1816500.0
#              05/2017   1800420.0
#              05/2018  10643770.0
#              06/2017   3521210.0
#              06/2018   6632560.0
#              07/2017   7182810.0
#              07/2018  43128530.0
#              08/2017   4339550.0
#              08/2018   7888670.0
#              09/2017   1689200.0
#              09/2018   4535740.0
#              10/2017    301990.0
#              10/2018   6721420.0
#              11/2017    429270.0
#              11/2018   7369120.0
#              12/2017    -34970.0
#              12/2018   6966000.0

# %%
output = pd.concat([grouped_1, grouped_2])

# %%
output
# Out:
#                          payoffs
#                              sum
# ContractName Y-M
# O1           06/2017    -20100.0
#              07/2017    -14300.0
# S1           01/2017    198300.0
#              02/2017    -97700.0
#              03/2017    -97700.0
# O2           01/2019  -1320540.0
#              02/2019  -1680820.0
#              03/2019    678800.0
#              04/2019   -730570.0
#              05/2019  -1097720.0
#              06/2019    773630.0
#              07/2019   3355940.0
#              08/2019  75340320.0
#              09/2019  39174380.0
#              10/2018    507430.0
#              11/2018    598010.0
#              12/2018     43140.0
# S2           01/2017   1481940.0
#              01/2018  12339910.0
#              02/2017  -1042810.0
#              02/2018    515440.0
#              03/2017    169240.0
#              03/2018   1194750.0
#              04/2017    295600.0
#              04/2018   1816500.0
#              05/2017   1800420.0
#              05/2018  10643770.0
#              06/2017   3521210.0
#              06/2018   6632560.0
#              07/2017   7182810.0
#              07/2018  43128530.0
#              08/2017   4339550.0
#              08/2018   7888670.0
#              09/2017   1689200.0
#              09/2018   4535740.0
#              10/2017    301990.0
#              10/2018   6721420.0
#              11/2017    429270.0
#              11/2018   7369120.0
#              12/2017    -34970.0
#              12/2018   6966000.0

# %% [markdown]
# # Task 9

# %%
output.reset_index(inplace=True, drop=False)
output.columns.to_list()
# Out:
# [('ContractName', ''), ('Y-M', ''), ('payoffs', 'sum')]

# %%
output.columns = ['ContractName', 'Y-M', 'TotalPayoff']

# %%
output['Year'] = output['Y-M'].apply(lambda x: x.split('/')[1])
output['Month'] = output['Y-M'].apply(lambda x: x.split('/')[0])
output.drop(['Y-M'],  axis=1, inplace=True)

# %%
output.to_csv(os.path.join(Output_folder, 'MonthlyContractPayoffs.csv'))

# %% [markdown]
# # Task 10

# %%
plantParameters
# Out:
#    PlantName  Year  Month PowerPriceName FuelPriceName  Capacity  HeatRate  \
# 0      Alpha  2017      1     HB_HOUSTON     Henry Hub       100       9.2
# 1      Alpha  2017      2     HB_HOUSTON     Henry Hub        98       9.4
# 2      Alpha  2017      3     HB_HOUSTON     Henry Hub        96       9.6
# 3      Alpha  2017      4     HB_HOUSTON     Henry Hub        94       9.8
# 4      Alpha  2017      5     HB_HOUSTON     Henry Hub        92      10.0
# 5      Alpha  2017      6     HB_HOUSTON     Henry Hub        90      10.0
# 6      Alpha  2017      7     HB_HOUSTON     Henry Hub        90      10.0
# 7      Alpha  2017      8     HB_HOUSTON     Henry Hub        92      10.0
# 8      Alpha  2017      9     HB_HOUSTON     Henry Hub        94       9.8
# 9      Alpha  2017     10     HB_HOUSTON     Henry Hub        96       9.6
# 10     Alpha  2017     11     HB_HOUSTON     Henry Hub        98       9.4
# 11     Alpha  2017     12     HB_HOUSTON     Henry Hub       100       9.2
# 12     Alpha  2018      1     HB_HOUSTON     Henry Hub       100       9.2
# 13     Alpha  2018      2     HB_HOUSTON     Henry Hub        98       9.4
# 14     Alpha  2018      3     HB_HOUSTON     Henry Hub        96       9.6
# 15     Alpha  2018      4     HB_HOUSTON     Henry Hub        94       9.8
# 16     Alpha  2018      5     HB_HOUSTON     Henry Hub        92      10.0
# 17     Alpha  2018      6     HB_HOUSTON     Henry Hub        90      10.0
# 18     Alpha  2018      7     HB_HOUSTON     Henry Hub        90      10.0
# 19     Alpha  2018      8     HB_HOUSTON     Henry Hub        92      10.0
# 20     Alpha  2018      9     HB_HOUSTON     Henry Hub        94       9.8
# 21     Alpha  2018     10     HB_HOUSTON     Henry Hub        96       9.6
# 22     Alpha  2018     11     HB_HOUSTON     Henry Hub        98       9.4
# 23     Alpha  2018     12     HB_HOUSTON     Henry Hub       100       9.2
# 24     Bravo  2017      1       HB_SOUTH    GDA_TETSTX       250       7.6
# 25     Bravo  2017      2       HB_SOUTH    GDA_TETSTX       245       7.7
# 26     Bravo  2017      3       HB_SOUTH    GDA_TETSTX       240       7.7
# 27     Bravo  2017      4       HB_SOUTH    GDA_TETSTX       235       7.8
# 28     Bravo  2017      5       HB_SOUTH    GDA_TETSTX       230       7.8
# 29     Bravo  2017      6       HB_SOUTH    GDA_TETSTX       225       7.9
# 30     Bravo  2017      7       HB_SOUTH    GDA_TETSTX       225       7.9
# 31     Bravo  2017      8       HB_SOUTH    GDA_TETSTX       230       7.8
# 32     Bravo  2017      9       HB_SOUTH    GDA_TETSTX       235       7.8
# 33     Bravo  2017     10       HB_SOUTH    GDA_TETSTX       240       7.7
# 34     Bravo  2017     11       HB_SOUTH    GDA_TETSTX       245       7.7
# 35     Bravo  2017     12       HB_SOUTH    GDA_TETSTX       250       7.6
# 36     Bravo  2018      1       HB_SOUTH    GDA_TETSTX       250       7.6
# 37     Bravo  2018      2       HB_SOUTH    GDA_TETSTX       245       7.7
# 38     Bravo  2018      3       HB_SOUTH    GDA_TETSTX       240       7.7
# 39     Bravo  2018      4       HB_SOUTH    GDA_TETSTX       235       7.8
# 40     Bravo  2018      5       HB_SOUTH    GDA_TETSTX       230       7.8
# 41     Bravo  2018      6       HB_SOUTH    GDA_TETSTX       225       7.9
# 42     Bravo  2018      7       HB_SOUTH    GDA_TETSTX       225       7.9
# 43     Bravo  2018      8       HB_SOUTH    GDA_TETSTX       230       7.8
# 44     Bravo  2018      9       HB_SOUTH    GDA_TETSTX       235       7.8
# 45     Bravo  2018     10       HB_SOUTH    GDA_TETSTX       240       7.7
# 46     Bravo  2018     11       HB_SOUTH    GDA_TETSTX       245       7.7
# 47     Bravo  2018     12       HB_SOUTH    GDA_TETSTX       250       7.6
#
#     VOM  FuelTransportationCost  FixedStartCost
# 0     3                    0.10           10000
# 1     3                    0.10           10000
# 2     3                    0.10           10000
# 3     3                    0.10           10000
# 4     3                    0.10           10000
# 5     3                    0.10           10000
# 6     3                    0.10           10000
# 7     3                    0.10           10000
# 8     3                    0.10           10000
# 9     3                    0.10           10000
# 10    3                    0.10           10000
# 11    3                    0.10           10000
# 12    3                    0.10           10000
# 13    3                    0.10           10000
# 14    3                    0.10           10000
# 15    3                    0.10           10000
# 16    3                    0.10           10000
# 17    3                    0.10           10000
# 18    3                    0.10           10000
# 19    3                    0.10           10000
# 20    3                    0.10           10000
# 21    3                    0.10           10000
# 22    3                    0.10           10000
# 23    3                    0.10           10000
# 24    2                    0.05           50000
# 25    2                    0.05           50000
# 26    2                    0.05           50000
# 27    2                    0.05           50000
# 28    2                    0.05           50000
# 29    2                    0.05           50000
# 30    2                    0.05           50000
# 31    2                    0.05           50000
# 32    2                    0.05           50000
# 33    2                    0.05           50000
# 34    2                    0.05           50000
# 35    2                    0.05           50000
# 36    2                    0.05           50000
# 37    2                    0.05           50000
# 38    2                    0.05           50000
# 39    2                    0.05           50000
# 40    2                    0.05           50000
# 41    2                    0.05           50000
# 42    2                    0.05           50000
# 43    2                    0.05           50000
# 44    2                    0.05           50000
# 45    2                    0.05           50000
# 46    2                    0.05           50000
# 47    2                    0.05           50000

# %%
fuelPrices['Year'] = pd.to_datetime(fuelPrices['Date']).dt.strftime('%Y')
fuelPrices['Month'] = pd.to_datetime(fuelPrices['Date']).dt.strftime('%m')

# %%
fuelPrices_17_18 = fuelPrices[(fuelPrices['Year'] =='2017') | (fuelPrices['Year'] == '2018')]

# %%
# fuelPrices_17_18.to_csv(os.path.join(Output_folder, 'test.csv'))

# %%
fuelPrices_17_18
# Out:
#         Variable       Date  Price  Year Month
# 121   GDA_TETSTX 2018-12-31  3.080  2018    12
# 122   GDA_TETSTX 2018-12-30  3.080  2018    12
# 123   GDA_TETSTX 2018-12-29  3.080  2018    12
# 124   GDA_TETSTX 2018-12-28  3.080  2018    12
# 125   GDA_TETSTX 2018-12-27  2.915  2018    12
# ...          ...        ...    ...   ...   ...
# 1091   Henry Hub 2018-12-27  3.215  2018    12
# 1092   Henry Hub 2018-12-28  3.065  2018    12
# 1093   Henry Hub 2018-12-29  3.065  2018    12
# 1094   Henry Hub 2018-12-30  3.065  2018    12
# 1095   Henry Hub 2018-12-31  3.065  2018    12
#
# [1460 rows x 5 columns]

# %%
fuelPrices_17_18_plantParameters = pd.merge(fuelPrices_17_18, plantParameters,  
                                      how='left', 
                                      left_on=['Variable','Year', 'Month'], 
                                      right_on = ['FuelPriceName','Year', 'Month'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-169-1e68372eb063> in <module>
# ----> 1 fuelPrices_17_18_plantParameters = pd.merge(fuelPrices_17_18, plantParameters,
#       2                                       how='left',
#       3                                       left_on=['Variable','Year', 'Month'],
#       4                                       right_on = ['FuelPriceName','Year', 'Month'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     670         # validate the merge keys dtypes. We may need to coerce
#     671         # to avoid incompatible dtypes
# --> 672         self._maybe_coerce_merge_keys()
#     673
#     674         # If argument passed to validate,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _maybe_coerce_merge_keys(self)
#    1195             # datetimelikes must match exactly
#    1196             elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
# -> 1197                 raise ValueError(msg)
#    1198             elif not needs_i8_conversion(lk.dtype) and needs_i8_conversion(rk.dtype):
#    1199                 raise ValueError(msg)
#
# ValueError: You are trying to merge on datetime64[ns] and int64 columns. If you wish to proceed you should use pd.concat
